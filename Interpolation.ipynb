# %%
#The need for interpolation

# %%
from scipy import *
from scipy.interpolate import *
import matplotlib.pyplot as plt

def f(x):           # function for signal
    return (5 * sin(x)) + (0.1 * x**2) + (0.01 * x**3)

n = 10
x = linspace(-2 * pi, 2 * pi, n)   # generating xdata
noise = randn(n)    # generating random noise
y = f(x) + noise        # adding noise to the signal

# plotting signal
fig, ax = plt.subplots()
ax.plot(x, y, 's', marker='.')  # the third argument creates a scatter plot
ax.set_title('Signal')
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/858336474.py:9: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   x = linspace(-2 * pi, 2 * pi, n)   # generating xdata
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/858336474.py:10: DeprecationWarning: scipy.randn is deprecated and will be removed in SciPy 2.0.0, use numpy.random.randn instead
#   noise = randn(n)    # generating random noise
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/858336474.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return (5 * sin(x)) + (0.1 * x**2) + (0.01 * x**3)
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/858336474.py:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(x, y, 's', marker='.')  # the third argument creates a scatter plot
# Text(0.5, 1.0, 'Signal')

# %%
#Implementation

# %%
from scipy import *
from scipy.interpolate import *
import matplotlib.pyplot as plt

def f(x):           # function for signal
    return (5 * sin(x)) + (0.1 * x**2) + (0.01 * x**3)

n = 10
x = linspace(-2*pi, 2*pi, n)   # generating xdata
noise = randn(n)    # generating random noise
y = f(x) + noise        # adding noise to the signal

x_plotter = linspace(-2*pi, 2*pi, 100)
y0 = interp1d(x, y, kind='linear')    # interpolation of type linear
y1 = interp1d(x, y, kind='quadratic')  # interpolation of type quadratic

# plotting the signal and interpolations
fig, ax = plt.subplots()

ax.plot(x, y, 's', marker='o', color='k', label='Noisy Data')  # signal
ax.plot(x_plotter, y0(x_plotter), label='linear') 
ax.plot(x_plotter, y1(x_plotter), label='quadratic') 
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Interpolation')

fig.tight_layout()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/2011320542.py:9: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   x = linspace(-2*pi, 2*pi, n)   # generating xdata
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/2011320542.py:10: DeprecationWarning: scipy.randn is deprecated and will be removed in SciPy 2.0.0, use numpy.random.randn instead
#   noise = randn(n)    # generating random noise
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/2011320542.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return (5 * sin(x)) + (0.1 * x**2) + (0.01 * x**3)
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/2011320542.py:13: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   x_plotter = linspace(-2*pi, 2*pi, 100)
# C:\Users\HP\AppData\Local\Temp/ipykernel_11500/2011320542.py:20: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(x, y, 's', marker='o', color='k', label='Noisy Data')  # signal
