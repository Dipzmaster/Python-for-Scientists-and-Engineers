# %%
#Finding local minima

# %%
from scipy import *
from scipy import optimize
import matplotlib.pyplot as plt

def f(x):
    return sin(x) -  (2 * exp(-(x - 0.4)**2))

x = arange(-7, 7, 0.1)
y = f(x)

point1 = -1.0 
point2 = 3.0 

min1 = optimize.fmin(f, point1)
min2 = optimize.fmin(f, point2)

fig, ax = plt.subplots(figsize=(12, 8)) 
ax.plot(x, y, label = '$\sin(x)-2e^{-(x-0.4)^2}$')  # plotting curve

ax.plot(min1, f(min1), 's', label='min 1', marker='v', color='r')    # plotting min1 
ax.plot(point1, f(point1), 's', label='start 1', marker='o', color='r')     # plotting starting point for min1

ax.plot(min2, f(min2), 's', label='min 2', marker='v', color='g')    # plotting min2 
ax.plot(point2, f(point2), 's', label='start 2', marker='o', color='g')     # plotting starting point for min2

ax.set_xlabel('x')
ax.grid()
ax.set_ylabel('y')
ax.legend(loc='best')
# Out:
# Optimization terminated successfully.
#          Current function value: -1.729779
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 17
#          Function evaluations: 34
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:8: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   x = arange(-7, 7, 0.1)
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:20: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(min1, f(min1), 's', label='min 1', marker='v', color='r')    # plotting min1
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:21: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(point1, f(point1), 's', label='start 1', marker='o', color='r')     # plotting starting point for min1
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(min2, f(min2), 's', label='min 2', marker='v', color='g')    # plotting min2
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2015869799.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(point2, f(point2), 's', label='start 2', marker='o', color='g')     # plotting starting point for min2

# %%
#Minima inside a bound

# %%
from scipy import *
from scipy import optimize
import matplotlib.pyplot as plt

def f(x):
    return sin(x) -  (2 * exp(-(x - 0.4)**2))

x = arange(-10, 10, 0.1)
y = f(x)

point1 = -2.0 
point2 = 6.0 

minima = optimize.fminbound(f, point1, point2)
print(minima)

fig, ax = plt.subplots(figsize=(12, 8)) 
ax.plot(x, y, label = '$\sin(x)-2e^{-(x-0.4)^2}$')  # plotting curve

ax.plot(minima, f(minima), 's', label='minima', marker='v', color='r')    # plotting min1 

ax.set_xlabel('x')
ax.grid()
ax.set_ylabel('y')
ax.legend(loc='best')
# Out:
# 0.134091356498235
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:8: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   x = arange(-10, 10, 0.1)
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:6: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:6: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return sin(x) -  (2 * exp(-(x - 0.4)**2))
# C:\Users\HP\AppData\Local\Temp/ipykernel_7272/2909341330.py:20: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s" (-> marker='s'). The keyword argument will take precedence.
#   ax.plot(minima, f(minima), 's', label='minima', marker='v', color='r')    # plotting min1
